# %% [markdown]
# <a href="https://colab.research.google.com/github/MaiKhoa0101/MachineLearning/blob/main/underthesea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install underthesea
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 47.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 61.1 MB/s eta 0:00:00
# ...

# %%
# GÁN NHÃN TỪ LOẠI
from underthesea import pos_tag
pos_tag('bạn ăn cơm chưa')
# Out:
# [('bạn', 'N'), ('ăn', 'V'), ('cơm', 'N'), ('chưa', 'R')]

# %%
pip install Cython

# %%
pip install joblib future scipy numpy scikit-learn

# %%
pip install -U fasttext --no-cache-dir --no-deps --force-reinstall
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 4.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp312-cp312-linux_x86_64.whl size=4647416 sha256=fadcd99d265c3596f6194a8d9b5c6df3158c6b97fe503dc98c1b81c305e72195
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yod8afu5/wheels/20/27/95/a7baf1b435f1cbde017cabdf1e9688526d2b0e929255a359c6
# Successfully built fasttext
# ...

# %%
pip install pyngrok

# %%
# !pip install flask flask-cors
from pyngrok import ngrok

# Tắt tất cả các tunnel đang chạy
ngrok.kill()

print("Đã tắt toàn bộ process ngrok cũ.")
from flask import Flask, request, jsonify
from underthesea import pos_tag, word_tokenize, classify
import json
from flask_cors import CORS

app = Flask(__name__)
CORS(app)

@app.route('/health', methods=['GET'])
def health():
    return jsonify({'status': 'ok'})

@app.route('/classify/pos', methods=['POST'])
def classify_pos():
    data = request.json
    text = data.get('text', '')
    result = pos_tag(text)
    return jsonify({
        'tokens': [word for word, tag in result],
        'pos_tags': [[word, tag] for word, tag in result],
        'success': True
    })

@app.route('/classify/tokenize', methods=['POST'])
def tokenize():
    data = request.json
    text = data.get('text', '')
    tokens = word_tokenize(text)
    return jsonify({
        'tokens': tokens,
        'success': True
    })

@app.route('/classify/text', methods=['POST'])
def classify_text():
    data = request.json
    text = data.get('text', '')
    result = classify(text)
    return jsonify({
        'classification': result,
        'success': True
    })

if __name__ == '__main__':
    # Expose URL công khai
    from flask import Flask
    from pyngrok import ngrok

    ngrok.set_auth_token("37kOuDP8SXUzcUwVz0Idz3EpOOu_6nA1e88jEujMWDNCA5qgv")  # Lấy từ https://dashboard.ngrok.com/
    public_url = ngrok.connect(5001)
    print(f"Flask server running at: {public_url}")

    app.run(host='0.0.0.0', port=5001, debug=False)
# Out:
# ...
# Đã tắt toàn bộ process ngrok cũ.
# Flask server running at: NgrokTunnel: "https://myles-undeliverable-symbolically.ngrok-free.dev" -> "http://localhost:5001"
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5001
#  * Running on http://172.28.0.12:5001
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [04/Mar/2026 12:28:46] "POST /classify/pos HTTP/1.1" 200 -

# %%
# PHÂN LOẠI VĂN BẢN
from underthesea import classify
classify('Tôi bị thủng màn nhỉ nên phải mổ để vá lại')

# %%
# PHÂN ĐOẠN TỪ
from underthesea import word_tokenize
sentence = 'Bệnh nhân Khoa có dấu hiệu bị ảo tưởng'
word_tokenize(sentence)
